# %% [markdown]
# # UFC Winner Prediction

# %% [markdown]
# *Course: Machine Learning Projects with TensorFlow 2.0 by Vlad Sebastian Ionescu*
#
# *Data: https://www.kaggle.com/rajeevw/ufcdata*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import os, datetime
# %load_ext tensorboard

print(tf.__version__)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# 2.0.0

# %% [markdown]
# ## 1. Load Data

# %%
data = pd.read_csv('data/preprocessed_data.csv').sample(frac=1)
data.head()
# Out:
#      Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 1565   Blue        True             5                    0.0
# 126    Blue       False             3                    0.0
# 63     Blue       False             3                    0.0
# 1356    Red       False             3                    1.0
# 465    Blue       False             3                    1.0
#
#       B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 1565                   2.0     0.0       29.000000          19.500000
# 126                    3.0     0.0       16.000000          13.333333
# 63                     1.0     0.0        5.500000           4.500000
# 1356                   0.0     0.0       13.583333           8.500000
# 465                    0.0     0.0       12.250000           7.000000
#
#       B_avg_CLINCH_att  B_avg_CLINCH_landed  ...  \
# 1565         19.000000            13.500000  ...
# 126          12.666667             9.666667  ...
# 63            4.500000             3.500000  ...
# 1356         10.250000             5.916667  ...
# 465           1.500000             1.000000  ...
#
#       weight_class_Women's Strawweight  B_Stance_Open Stance  \
# 1565                                 1                     0
# 126                                  0                     0
# 63                                   0                     0
# 1356                                 0                     0
# 465                                  0                     0
#
#       B_Stance_Orthodox  B_Stance_Sideways  B_Stance_Southpaw  \
# 1565                  1                  0                  0
# 126                   0                  0                  0
# 63                    0                  0                  0
# 1356                  1                  0                  0
# 465                   1                  0                  0
#
#       B_Stance_Switch  R_Stance_Open Stance  R_Stance_Orthodox  \
# 1565                0                     0                  1
# 126                 1                     0                  1
# 63                  1                     0                  0
# 1356                0                     0                  1
# 465                 0                     0                  1
#
#       R_Stance_Southpaw  R_Stance_Switch
# 1565                  0                0
# 126                   0                0
# 63                    1                0
# 1356                  0                0
# 465                   0                0
#
# [5 rows x 160 columns]

# %% [markdown]
# ## 2. Data Processing

# %%
data['Winner'] = data['Winner'].map(lambda x: 1 if x=='Red' else 0)
data['title_bout'] = data['title_bout'].map(lambda x: 1 if x=='Red' else 0)

# %%
data.head()
# Out:
#       Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 1565       0           0             5                    0.0
# 126        0           0             3                    0.0
# 63         0           0             3                    0.0
# 1356       1           0             3                    1.0
# 465        0           0             3                    1.0
#
#       B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 1565                   2.0     0.0       29.000000          19.500000
# 126                    3.0     0.0       16.000000          13.333333
# 63                     1.0     0.0        5.500000           4.500000
# 1356                   0.0     0.0       13.583333           8.500000
# 465                    0.0     0.0       12.250000           7.000000
#
#       B_avg_CLINCH_att  B_avg_CLINCH_landed  ...  \
# 1565         19.000000            13.500000  ...
# 126          12.666667             9.666667  ...
# 63            4.500000             3.500000  ...
# 1356         10.250000             5.916667  ...
# 465           1.500000             1.000000  ...
#
#       weight_class_Women's Strawweight  B_Stance_Open Stance  \
# 1565                                 1                     0
# 126                                  0                     0
# 63                                   0                     0
# 1356                                 0                     0
# 465                                  0                     0
#
#       B_Stance_Orthodox  B_Stance_Sideways  B_Stance_Southpaw  \
# 1565                  1                  0                  0
# 126                   0                  0                  0
# 63                    0                  0                  0
# 1356                  1                  0                  0
# 465                   1                  0                  0
#
#       B_Stance_Switch  R_Stance_Open Stance  R_Stance_Orthodox  \
# 1565                0                     0                  1
# 126                 1                     0                  1
# 63                  1                     0                  0
# 1356                0                     0                  1
# 465                 0                     0                  1
#
#       R_Stance_Southpaw  R_Stance_Switch
# 1565                  0                0
# 126                   0                0
# 63                    1                0
# 1356                  0                0
# 465                   0                0
#
# [5 rows x 160 columns]

# %%
data.describe()
# Out:
#             Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# count  3592.000000      3592.0   3592.000000            3592.000000
# mean      0.662584         0.0      3.196548               0.560412
# std       0.472894         0.0      0.664834               0.790660
# min       0.000000         0.0      1.000000               0.000000
# 25%       0.000000         0.0      3.000000               0.000000
# 50%       1.000000         0.0      3.000000               0.000000
# 75%       1.000000         0.0      3.000000               1.000000
# max       1.000000         0.0      5.000000               6.000000
#
#        B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# count           3592.000000  3592.0     3592.000000        3592.000000
# mean               1.126114     0.0        8.800322           6.158010
# std                1.385555     0.0        7.099821           5.077738
# min                0.000000     0.0        0.000000           0.000000
# 25%                0.000000     0.0        3.666667           2.500000
# 50%                1.000000     0.0        7.000000           5.000000
# 75%                2.000000     0.0       12.275974           8.500000
# max               12.000000     0.0       49.000000          39.000000
#
#        B_avg_CLINCH_att  B_avg_CLINCH_landed  ...  \
# count       3592.000000          3592.000000  ...
# mean           8.308673             5.615597  ...
# std            7.518370             5.415420  ...
# min            0.000000             0.000000  ...
# 25%            3.000000             2.000000  ...
# 50%            6.467611             4.275253  ...
# 75%           11.500000             7.857143  ...
# max           87.000000            68.000000  ...
#
#        weight_class_Women's Strawweight  B_Stance_Open Stance  \
# count                       3592.000000           3592.000000
# mean                           0.027283              0.001392
# std                            0.162929              0.037288
# min                            0.000000              0.000000
# 25%                            0.000000              0.000000
# 50%                            0.000000              0.000000
# 75%                            0.000000              0.000000
# max                            1.000000              1.000000
#
#        B_Stance_Orthodox  B_Stance_Sideways  B_Stance_Southpaw  \
# count        3592.000000        3592.000000        3592.000000
# mean            0.768931           0.000557           0.197383
# std             0.421575           0.023593           0.398079
# min             0.000000           0.000000           0.000000
# 25%             1.000000           0.000000           0.000000
# 50%             1.000000           0.000000           0.000000
# 75%             1.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        B_Stance_Switch  R_Stance_Open Stance  R_Stance_Orthodox  \
# count      3592.000000           3592.000000        3592.000000
# mean          0.031737              0.003341           0.758352
# std           0.175324              0.057711           0.428142
# min           0.000000              0.000000           0.000000
# 25%           0.000000              0.000000           1.000000
# 50%           0.000000              0.000000           1.000000
# 75%           0.000000              0.000000           1.000000
# max           1.000000              1.000000           1.000000
#
#        R_Stance_Southpaw  R_Stance_Switch
# count        3592.000000      3592.000000
# mean            0.210746         0.027561
# std             0.407895         0.163735
# min             0.000000         0.000000
# 25%             0.000000         0.000000
# 50%             0.000000         0.000000
# 75%             0.000000         0.000000
# max             1.000000         1.000000
#
# [8 rows x 160 columns]

# %%
train_size = int(0.7*len(data))
features = data.drop(columns=['Winner'])
target = data['Winner']
X_train, X_test = features.values[:train_size], features.values[train_size:]
y_train, y_test = target.values[:train_size], target.values[train_size:]

# %%
corr = data.corr()
cmap = sns.diverging_palette(250, 10, as_cmap=True)
#plt.figure(figsize=(40, 80))
#sns.heatmap(corr[['Winner']], square=True, cmap=cmap, 
#            annot=True, vmax=3, cbar_kws={'shrink':.5}, linewidths=.5)

# %% [markdown]
# ## 3. TF ANN

# %%
# %reload_ext tensorboard

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation=tf.nn.leaky_relu), # x if x>0, else alpha*x
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation=tf.nn.leaky_relu), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# We give more weight to the class that is under represented (blue)
red = len(y_train[y_train>0])
blue = len(y_train) - red
total = len(y_train)
weight_red = total / (2*red)
weight_blue = total / (2*blue)
class_weight = {0: weight_blue, 1: weight_red}
print(class_weight)

adam_optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.MAE

model.compile(
    optimizer=adam_optimizer,
    loss = 'binary_crossentropy', 
    metrics=[tf.keras.metrics.TruePositives(name='tp'),
             tf.keras.metrics.FalsePositives(name='fp'),
             tf.keras.metrics.TrueNegatives(name='tn'),
             tf.keras.metrics.FalseNegatives(name='fn'),      
             tf.keras.metrics.BinaryAccuracy(name='accuracy'), 
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall'), 
             tf.keras.metrics.AUC(name='auc')
            ])

save_best_callback = tf.keras.callbacks.ModelCheckpoint('models/model-{epoch:02d}-{val_accuracy:.2f}.hdf5', 
                                                        monitor='val_accuracy', 
                                                        verbose=1, 
                                                        save_best_only=True, 
                                                        save_weights_only=False, 
                                                        save_frequency=1)

logdir = os.path.join('tflogs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1, profile_batch=0)

# %tensorboard --logdir tflogs

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(X_train)

model.fit(x_train_scaled, y_train, 
          epochs=30, 
          class_weight=class_weight,
          batch_size=64,
          validation_split=0.1,
          callbacks=[tensorboard_callback]
         )
# Out:
# {0: 1.4684579439252337, 1: 0.7581423401688782}
# Reusing TensorBoard on port 6006 (pid 8880), started 0:07:51 ago. (Use '!kill 8880' to kill it.)
#       <iframe id="tensorboard-frame-d6a8402eb69bb34f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d6a8402eb69bb34f");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
# Train on 2262 samples, validate on 252 samples
# Epoch 1/30
# 2262/2262 [==============================] - 9s 4ms/sample - loss: 0.7503 - tp: 861.0000 - fp: 333.0000 - tn: 437.0000 - fn: 631.0000 - accuracy: 0.5738 - precision: 0.7211 - recall: 0.5771 - auc: 0.5960 - val_loss: 0.6896 - val_tp: 107.0000 - val_fp: 44.0000 - val_tn: 42.0000 - val_fn: 59.0000 - val_accuracy: 0.5913 - val_precision: 0.7086 - val_recall: 0.6446 - val_auc: 0.6056
# Epoch 2/30
# 2262/2262 [==============================] - 1s 588us/sample - loss: 0.6708 - tp: 918.0000 - fp: 289.0000 - tn: 481.0000 - fn: 574.0000 - accuracy: 0.6185 - precision: 0.7606 - recall: 0.6153 - auc: 0.6579 - val_loss: 0.6485 - val_tp: 109.0000 - val_fp: 34.0000 - val_tn: 52.0000 - val_fn: 57.0000 - val_accuracy: 0.6389 - val_precision: 0.7622 - val_recall: 0.6566 - val_auc: 0.6668
# Epoch 3/30
# 2262/2262 [==============================] - 1s 536us/sample - loss: 0.6204 - tp: 961.0000 - fp: 238.0000 - tn: 532.0000 - fn: 531.0000 - accuracy: 0.6600 - precision: 0.8015 - recall: 0.6441 - auc: 0.7161 - val_loss: 0.6497 - val_tp: 107.0000 - val_fp: 43.0000 - val_tn: 43.0000 - val_fn: 59.0000 - val_accuracy: 0.5952 - val_precision: 0.7133 - val_recall: 0.6446 - val_auc: 0.6541
# Epoch 4/30
# 2262/2262 [==============================] - 1s 498us/sample - loss: 0.6157 - tp: 947.0000 - fp: 222.0000 - tn: 548.0000 - fn: 545.0000 - accuracy: 0.6609 - precision: 0.8101 - recall: 0.6347 - auc: 0.7246 - val_loss: 0.6585 - val_tp: 122.0000 - val_fp: 47.0000 - val_tn: 39.0000 - val_fn: 44.0000 - val_accuracy: 0.6389 - val_precision: 0.7219 - val_recall: 0.7349 - val_auc: 0.6575
# Epoch 5/30
# 2262/2262 [==============================] - 1s 352us/sample - loss: 0.6109 - tp: 966.0000 - fp: 236.0000 - tn: 534.0000 - fn: 526.0000 - accuracy: 0.6631 - precision: 0.8037 - recall: 0.6475 - auc: 0.7303 - val_loss: 0.6517 - val_tp: 105.0000 - val_fp: 36.0000 - val_tn: 50.0000 - val_fn: 61.0000 - val_accuracy: 0.6151 - val_precision: 0.7447 - val_recall: 0.6325 - val_auc: 0.6596
# Epoch 6/30
# 2262/2262 [==============================] - 1s 507us/sample - loss: 0.5851 - tp: 983.0000 - fp: 222.0000 - tn: 548.0000 - fn: 509.0000 - accuracy: 0.6768 - precision: 0.8158 - recall: 0.6588 - auc: 0.7519 - val_loss: 0.6622 - val_tp: 96.0000 - val_fp: 34.0000 - val_tn: 52.0000 - val_fn: 70.0000 - val_accuracy: 0.5873 - val_precision: 0.7385 - val_recall: 0.5783 - val_auc: 0.6434
# Epoch 7/30
# 2262/2262 [==============================] - 1s 457us/sample - loss: 0.5843 - tp: 972.0000 - fp: 215.0000 - tn: 555.0000 - fn: 520.0000 - accuracy: 0.6751 - precision: 0.8189 - recall: 0.6515 - auc: 0.7552 - val_loss: 0.6562 - val_tp: 95.0000 - val_fp: 30.0000 - val_tn: 56.0000 - val_fn: 71.0000 - val_accuracy: 0.5992 - val_precision: 0.7600 - val_recall: 0.5723 - val_auc: 0.6578
# Epoch 8/30
# 2262/2262 [==============================] - 1s 388us/sample - loss: 0.5721 - tp: 996.0000 - fp: 193.0000 - tn: 577.0000 - fn: 496.0000 - accuracy: 0.6954 - precision: 0.8377 - recall: 0.6676 - auc: 0.7687 - val_loss: 0.6472 - val_tp: 116.0000 - val_fp: 42.0000 - val_tn: 44.0000 - val_fn: 50.0000 - val_accuracy: 0.6349 - val_precision: 0.7342 - val_recall: 0.6988 - val_auc: 0.6838
# Epoch 9/30
# 2262/2262 [==============================] - 1s 581us/sample - loss: 0.5696 - tp: 998.0000 - fp: 213.0000 - tn: 557.0000 - fn: 494.0000 - accuracy: 0.6874 - precision: 0.8241 - recall: 0.6689 - auc: 0.7689 - val_loss: 0.6423 - val_tp: 104.0000 - val_fp: 32.0000 - val_tn: 54.0000 - val_fn: 62.0000 - val_accuracy: 0.6270 - val_precision: 0.7647 - val_recall: 0.6265 - val_auc: 0.6800
# Epoch 10/30
# 2262/2262 [==============================] - 1s 485us/sample - loss: 0.5709 - tp: 1001.0000 - fp: 188.0000 - tn: 582.0000 - fn: 491.0000 - accuracy: 0.6998 - precision: 0.8419 - recall: 0.6709 - auc: 0.7715 - val_loss: 0.6611 - val_tp: 118.0000 - val_fp: 44.0000 - val_tn: 42.0000 - val_fn: 48.0000 - val_accuracy: 0.6349 - val_precision: 0.7284 - val_recall: 0.7108 - val_auc: 0.6739
# Epoch 11/30
# 2262/2262 [==============================] - 1s 393us/sample - loss: 0.5533 - tp: 1012.0000 - fp: 189.0000 - tn: 581.0000 - fn: 480.0000 - accuracy: 0.7042 - precision: 0.8426 - recall: 0.6783 - auc: 0.7881 - val_loss: 0.6441 - val_tp: 114.0000 - val_fp: 37.0000 - val_tn: 49.0000 - val_fn: 52.0000 - val_accuracy: 0.6468 - val_precision: 0.7550 - val_recall: 0.6867 - val_auc: 0.6817
# Epoch 12/30
# 2262/2262 [==============================] - 1s 373us/sample - loss: 0.5519 - tp: 1025.0000 - fp: 179.0000 - tn: 591.0000 - fn: 467.0000 - accuracy: 0.7144 - precision: 0.8513 - recall: 0.6870 - auc: 0.7950 - val_loss: 0.6563 - val_tp: 113.0000 - val_fp: 40.0000 - val_tn: 46.0000 - val_fn: 53.0000 - val_accuracy: 0.6310 - val_precision: 0.7386 - val_recall: 0.6807 - val_auc: 0.6807
# Epoch 13/30
# 2262/2262 [==============================] - 1s 381us/sample - loss: 0.5459 - tp: 1033.0000 - fp: 200.0000 - tn: 570.0000 - fn: 459.0000 - accuracy: 0.7087 - precision: 0.8378 - recall: 0.6924 - auc: 0.7916 - val_loss: 0.6745 - val_tp: 118.0000 - val_fp: 44.0000 - val_tn: 42.0000 - val_fn: 48.0000 - val_accuracy: 0.6349 - val_precision: 0.7284 - val_recall: 0.7108 - val_auc: 0.6606
# Epoch 14/30
# 2262/2262 [==============================] - 1s 438us/sample - loss: 0.5381 - tp: 1035.0000 - fp: 202.0000 - tn: 568.0000 - fn: 457.0000 - accuracy: 0.7087 - precision: 0.8367 - recall: 0.6937 - auc: 0.8007 - val_loss: 0.6742 - val_tp: 120.0000 - val_fp: 45.0000 - val_tn: 41.0000 - val_fn: 46.0000 - val_accuracy: 0.6389 - val_precision: 0.7273 - val_recall: 0.7229 - val_auc: 0.6583
# Epoch 15/30
# 2262/2262 [==============================] - 1s 406us/sample - loss: 0.5265 - tp: 1068.0000 - fp: 204.0000 - tn: 566.0000 - fn: 424.0000 - accuracy: 0.7224 - precision: 0.8396 - recall: 0.7158 - auc: 0.8084 - val_loss: 0.6643 - val_tp: 107.0000 - val_fp: 36.0000 - val_tn: 50.0000 - val_fn: 59.0000 - val_accuracy: 0.6230 - val_precision: 0.7483 - val_recall: 0.6446 - val_auc: 0.6725
# Epoch 16/30
# 2262/2262 [==============================] - 1s 432us/sample - loss: 0.5182 - tp: 1061.0000 - fp: 175.0000 - tn: 595.0000 - fn: 431.0000 - accuracy: 0.7321 - precision: 0.8584 - recall: 0.7111 - auc: 0.8191 - val_loss: 0.6692 - val_tp: 109.0000 - val_fp: 32.0000 - val_tn: 54.0000 - val_fn: 57.0000 - val_accuracy: 0.6468 - val_precision: 0.7730 - val_recall: 0.6566 - val_auc: 0.6783
# Epoch 17/30
# 2262/2262 [==============================] - 1s 520us/sample - loss: 0.5038 - tp: 1062.0000 - fp: 168.0000 - tn: 602.0000 - fn: 430.0000 - accuracy: 0.7356 - precision: 0.8634 - recall: 0.7118 - auc: 0.8306 - val_loss: 0.6670 - val_tp: 120.0000 - val_fp: 39.0000 - val_tn: 47.0000 - val_fn: 46.0000 - val_accuracy: 0.6627 - val_precision: 0.7547 - val_recall: 0.7229 - val_auc: 0.6844
# Epoch 18/30
# 2262/2262 [==============================] - 1s 556us/sample - loss: 0.5064 - tp: 1065.0000 - fp: 180.0000 - tn: 590.0000 - fn: 427.0000 - accuracy: 0.7317 - precision: 0.8554 - recall: 0.7138 - auc: 0.8242 - val_loss: 0.6590 - val_tp: 118.0000 - val_fp: 35.0000 - val_tn: 51.0000 - val_fn: 48.0000 - val_accuracy: 0.6706 - val_precision: 0.7712 - val_recall: 0.7108 - val_auc: 0.6959
# Epoch 19/30
# 2262/2262 [==============================] - 1s 454us/sample - loss: 0.5073 - tp: 1053.0000 - fp: 168.0000 - tn: 602.0000 - fn: 439.0000 - accuracy: 0.7317 - precision: 0.8624 - recall: 0.7058 - auc: 0.8259 - val_loss: 0.6887 - val_tp: 116.0000 - val_fp: 43.0000 - val_tn: 43.0000 - val_fn: 50.0000 - val_accuracy: 0.6310 - val_precision: 0.7296 - val_recall: 0.6988 - val_auc: 0.6739
# Epoch 20/30
# 2262/2262 [==============================] - 1s 459us/sample - loss: 0.4750 - tp: 1125.0000 - fp: 172.0000 - tn: 598.0000 - fn: 367.0000 - accuracy: 0.7617 - precision: 0.8674 - recall: 0.7540 - auc: 0.8504 - val_loss: 0.7086 - val_tp: 116.0000 - val_fp: 44.0000 - val_tn: 42.0000 - val_fn: 50.0000 - val_accuracy: 0.6270 - val_precision: 0.7250 - val_recall: 0.6988 - val_auc: 0.6619
# Epoch 21/30
# 2262/2262 [==============================] - 2s 717us/sample - loss: 0.4848 - tp: 1081.0000 - fp: 147.0000 - tn: 623.0000 - fn: 411.0000 - accuracy: 0.7533 - precision: 0.8803 - recall: 0.7245 - auc: 0.8434 - val_loss: 0.6931 - val_tp: 117.0000 - val_fp: 44.0000 - val_tn: 42.0000 - val_fn: 49.0000 - val_accuracy: 0.6310 - val_precision: 0.7267 - val_recall: 0.7048 - val_auc: 0.6694
# Epoch 22/30
# 2262/2262 [==============================] - 1s 509us/sample - loss: 0.4760 - tp: 1089.0000 - fp: 159.0000 - tn: 611.0000 - fn: 403.0000 - accuracy: 0.7515 - precision: 0.8726 - recall: 0.7299 - auc: 0.8486 - val_loss: 0.6997 - val_tp: 124.0000 - val_fp: 41.0000 - val_tn: 45.0000 - val_fn: 42.0000 - val_accuracy: 0.6706 - val_precision: 0.7515 - val_recall: 0.7470 - val_auc: 0.6849
# Epoch 23/30
# 2262/2262 [==============================] - 1s 573us/sample - loss: 0.4608 - tp: 1117.0000 - fp: 146.0000 - tn: 624.0000 - fn: 375.0000 - accuracy: 0.7697 - precision: 0.8844 - recall: 0.7487 - auc: 0.8616 - val_loss: 0.6911 - val_tp: 120.0000 - val_fp: 42.0000 - val_tn: 44.0000 - val_fn: 46.0000 - val_accuracy: 0.6508 - val_precision: 0.7407 - val_recall: 0.7229 - val_auc: 0.6890
# Epoch 24/30
# 2262/2262 [==============================] - 1s 479us/sample - loss: 0.4819 - tp: 1108.0000 - fp: 173.0000 - tn: 597.0000 - fn: 384.0000 - accuracy: 0.7538 - precision: 0.8649 - recall: 0.7426 - auc: 0.8449 - val_loss: 0.6806 - val_tp: 119.0000 - val_fp: 40.0000 - val_tn: 46.0000 - val_fn: 47.0000 - val_accuracy: 0.6548 - val_precision: 0.7484 - val_recall: 0.7169 - val_auc: 0.6931
# Epoch 25/30
# 2262/2262 [==============================] - 1s 528us/sample - loss: 0.4612 - tp: 1109.0000 - fp: 136.0000 - tn: 634.0000 - fn: 383.0000 - accuracy: 0.7706 - precision: 0.8908 - recall: 0.7433 - auc: 0.8614 - val_loss: 0.7184 - val_tp: 116.0000 - val_fp: 46.0000 - val_tn: 40.0000 - val_fn: 50.0000 - val_accuracy: 0.6190 - val_precision: 0.7160 - val_recall: 0.6988 - val_auc: 0.6699
# Epoch 26/30
# 2262/2262 [==============================] - 2s 692us/sample - loss: 0.4500 - tp: 1156.0000 - fp: 153.0000 - tn: 617.0000 - fn: 336.0000 - accuracy: 0.7838 - precision: 0.8831 - recall: 0.7748 - auc: 0.8696 - val_loss: 0.6901 - val_tp: 115.0000 - val_fp: 38.0000 - val_tn: 48.0000 - val_fn: 51.0000 - val_accuracy: 0.6468 - val_precision: 0.7516 - val_recall: 0.6928 - val_auc: 0.6956
# Epoch 27/30
# 2262/2262 [==============================] - 2s 795us/sample - loss: 0.4527 - tp: 1139.0000 - fp: 165.0000 - tn: 605.0000 - fn: 353.0000 - accuracy: 0.7710 - precision: 0.8735 - recall: 0.7634 - auc: 0.8657 - val_loss: 0.6896 - val_tp: 115.0000 - val_fp: 33.0000 - val_tn: 53.0000 - val_fn: 51.0000 - val_accuracy: 0.6667 - val_precision: 0.7770 - val_recall: 0.6928 - val_auc: 0.6996
# Epoch 28/30
# 2262/2262 [==============================] - 2s 757us/sample - loss: 0.4466 - tp: 1126.0000 - fp: 132.0000 - tn: 638.0000 - fn: 366.0000 - accuracy: 0.7798 - precision: 0.8951 - recall: 0.7547 - auc: 0.8693 - val_loss: 0.7215 - val_tp: 125.0000 - val_fp: 44.0000 - val_tn: 42.0000 - val_fn: 41.0000 - val_accuracy: 0.6627 - val_precision: 0.7396 - val_recall: 0.7530 - val_auc: 0.6858
# Epoch 29/30
# 2262/2262 [==============================] - 1s 561us/sample - loss: 0.4411 - tp: 1156.0000 - fp: 146.0000 - tn: 624.0000 - fn: 336.0000 - accuracy: 0.7869 - precision: 0.8879 - recall: 0.7748 - auc: 0.8748 - val_loss: 0.7205 - val_tp: 122.0000 - val_fp: 44.0000 - val_tn: 42.0000 - val_fn: 44.0000 - val_accuracy: 0.6508 - val_precision: 0.7349 - val_recall: 0.7349 - val_auc: 0.6839
# Epoch 30/30
# 2262/2262 [==============================] - 1s 581us/sample - loss: 0.4418 - tp: 1137.0000 - fp: 137.0000 - tn: 633.0000 - fn: 355.0000 - accuracy: 0.7825 - precision: 0.8925 - recall: 0.7621 - auc: 0.8739 - val_loss: 0.7089 - val_tp: 118.0000 - val_fp: 46.0000 - val_tn: 40.0000 - val_fn: 48.0000 - val_accuracy: 0.6270 - val_precision: 0.7195 - val_recall: 0.7108 - val_auc: 0.6861

# %%
#loaded_model = tf.keras.models.load_model('models/model-50-0.61.hdf5')
#print(loaded_model.summary())
x_test_scaled = scaler.fit_transform(X_test)
model.evaluate(x_test_scaled, y_test, verbose=2)
#np.round(model.predict(X_test))
# Out:
# 1078/1 - 1s - loss: 1.1980 - accuracy: 0.6466 - precision: 0.7418
# [1.241041070676248, 0.6465677, 0.741844]
